# %%
#Import necessary libraries
import pandas as pd

# %%
#Load the dataset 1
geo = pd.read_csv("01.geo.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(geo.isnull().sum().sum())

#Total missing values for each feature
print(geo.isnull().sum())
# Out:
# 0
# geo_city                    0
# geo_latitude                0
# geo_longitude               0
# geo_admin1_code             0
# geo_autonomous_community    0
# dtype: int64

# %%
#Load the dataset 2
customers = pd.read_csv("02.customers.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(customers.isnull().sum().sum())

#Total missing values for each feature
print(customers.isnull().sum())
# Out:
# 0
# customer_id                      0
# customer_unique_id               0
# customer_autonomous_community    0
# customer_city                    0
# dtype: int64

# %%
#Load the dataset 3
sellers = pd.read_csv("03.sellers.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(sellers.isnull().sum().sum())

#Total missing values for each feature
print(sellers.isnull().sum())
# Out:
# 0
# seller_id                      0
# seller_autonomous_community    0
# seller_city                    0
# dtype: int64

# %%
#Load the dataset 4
order_status = pd.read_csv("04.order_status.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(order_status.isnull().sum().sum())

#Total missing values for each feature
print(order_status.isnull().sum())
# Out:
# 4931
# order_id                          9
# customer_id                       0
# order_status                      0
# ts_order_purchase                 0
# ts_order_approved               162
# ts_order_delivered_carrier     1787
# ts_order_delivered_customer    2969
# ts_order_estimated_delivery       4
# s_time                            0
# dtype: int64

# %%
order_status
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99445  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99446  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99447  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99448  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99449  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status ts_order_purchase ts_order_approved  \
# ...

# %%
order_status.dropna(subset=['order_id'], inplace=True)
order_status
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99445  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99446  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99447  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99448  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99449  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status ts_order_purchase ts_order_approved  \
# ...

# %%
#Load the dataset 5
order_items = pd.read_csv("05.order_items.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(order_items.isnull().sum().sum())

#Total missing values for each feature
print(order_items.isnull().sum())
# Out:
# 5
# order_id                    5
# order_item_sequence_id      0
# product_id                  0
# price                       0
# shipping_cost               0
# seller_id                   0
# max_shipping_seller_date    0
# dtype: int64

# %%
order_items["order_id"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 112650    False
# 112651    False
# 112652    False
# 112653    False
# 112654    False
# Name: order_id, Length: 112655, dtype: bool

# %%
order_items.dropna()
# Out:
#                                 order_id  order_item_sequence_id  \
# 0       e5fa5a7210941f7d56d0208e4e071d35                       1
# 1       bfbd0f9bdef84302105ad712db648a6c                       1
# 2       bfbd0f9bdef84302105ad712db648a6c                       2
# 3       bfbd0f9bdef84302105ad712db648a6c                       3
# 4       cd3b8574c82b42fc8129f6d502690c3e                       1
# ...                                  ...                     ...
# 112650  3b61aab5de69abc1731138bd104a777f                       1
# 112651  9c94a4ea2f7876660fa6f1b59b69c8e6                       1
# 112652  13bdf405f961a6deec817d817f5c6624                       1
# 112653  c2bb89b5c1dd978d507284be78a04cb2                       1
# 112654  c2bb89b5c1dd978d507284be78a04cb2                       2
#
#                               product_id   price shipping_cost  \
# 0       f3c2d01a84c947b078e32bbef0718962    59,5         15,56
# ...

# %%
#Load the dataset 6
order_payments = pd.read_csv("06.order_payments.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(order_payments.isnull().sum().sum())

#Total missing values for each feature
print(order_payments.isnull().sum())
# Out:
# 12
# order_id                         12
# payment_method                    0
# payment_method_sequence_id        0
# payment_installments_quantity     0
# transaction_value                 0
# dtype: int64

# %%
order_payments["order_id"].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103893    False
# 103894    False
# 103895    False
# 103896    False
# 103897    False
# Name: order_id, Length: 103898, dtype: bool

# %%
order_payments.dropna()
# Out:
#                                 order_id payment_method  \
# 0       b81ef226f3fe1789b1e8b2acac839d17    credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0    credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd    credit_card
# 3       ba78997921bbcdc1373bb41e913ab953    credit_card
# 4       42fdf880ba16b47b59251dd489d4441a    credit_card
# ...                                  ...            ...
# 103893  0406037ad97740d563a178ecc7a2075c           cash
# 103894  7b905861d7c825891d6347454ea7863f    credit_card
# 103895  32609bbb3dd69b3c066a6860554a77bf    credit_card
# 103896  b8b61059626efa996a60be9bb9320e10    credit_card
# 103897  28bbae6599b09d39ca406b747b6632b1           cash
#
#         payment_method_sequence_id  payment_installments_quantity  \
# 0                                1                              8
# 1                                1                              1
# 2                                1                              1
# ...

# %%
#Load the dataset 7
product_reviews = pd.read_csv("07.product_reviews.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(product_reviews.isnull().sum().sum())

#Total missing values for each feature
print(product_reviews.isnull().sum())
# Out:
# 0
# order_id        0
# product_id      0
# review_score    0
# review_date     0
# dtype: int64

# %%
#Load the dataset 8
products = pd.read_csv("08.products.csv", sep=";", encoding = "ISO-8859-1")

#Check for standard missing values
print(products.isnull().sum().sum())

#Total missing values for each feature
print(products.isnull().sum())
# Out:
# 1228
# product_id                  0
# product_category_name     610
# product_weight_gr           2
# product_length_cm           2
# product_height_cm           2
# product_width_cm            2
# product_photo_quantity    610
# dtype: int64

# %%
merged_Frame = pd.merge(order_items, order_status, on = "order_id", how='inner')
merged_Frame
# Out:
#                                 order_id  order_item_sequence_id  \
# 0       e5fa5a7210941f7d56d0208e4e071d35                       1
# 1       bfbd0f9bdef84302105ad712db648a6c                       1
# 2       bfbd0f9bdef84302105ad712db648a6c                       2
# 3       bfbd0f9bdef84302105ad712db648a6c                       3
# 4       cd3b8574c82b42fc8129f6d502690c3e                       1
# ...                                  ...                     ...
# 112645  3b61aab5de69abc1731138bd104a777f                       1
# 112646  9c94a4ea2f7876660fa6f1b59b69c8e6                       1
# 112647  13bdf405f961a6deec817d817f5c6624                       1
# 112648  c2bb89b5c1dd978d507284be78a04cb2                       1
# 112649  c2bb89b5c1dd978d507284be78a04cb2                       2
#
#                               product_id   price shipping_cost  \
# 0       f3c2d01a84c947b078e32bbef0718962    59,5         15,56
# ...

# %%
mF = merged_Frame.sort_values('order_id', ignore_index=True)
mF
# Out:
#                                 order_id  order_item_sequence_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214                       1
# 1       00018f77f2f0320c557190d7a144bdd3                       1
# 2       000229ec398224ef6ca0657da4fc703e                       1
# 3       00024acbcdf0a6daa1e931b038114c75                       1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9                       1
# ...                                  ...                     ...
# 112645  fffc94f6ce00a00581880bf54a75a037                       1
# 112646  fffcd46ef2263f404302a634eb57f7eb                       1
# 112647  fffce4705a9662cd70adb13d4a31832d                       1
# 112648  fffe18544ffabc95dfada21779c9644f                       1
# 112649  fffe41c64501cc87c801fd61db3f6244                       1
#
#                               product_id   price shipping_cost  \
# 0       4244733e06e7ecb4970a6e2683c13e61    58,9         13,29
# ...

# %%
merged_Frame.to_csv('merged_Frame.csv')

# %%
merged_Frame.to_excel('merged_Frame.xlsx')
